# %%
import os
import pandas as pd

DATADIR = "DB_NG"
DATAFILE = "n_gait_data.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'VL', 'GM', 'SM', 
                                                                    'BF'])

df = df.dropna()
df.tail()
# Out:
#           Time        VL        GM        SM        BF
# 27995  13.9975  0.347619 -0.208621  0.327434  0.473832
# 27996  13.9980  0.347619 -0.208621  0.327434  0.473832
# 27997  13.9985  0.347619 -0.208621  0.327434  0.473832
# 27998  13.9990  0.347619 -0.208621  0.327434  0.473832
# 27999  13.9995  0.347619 -0.208621  0.327434  0.473832

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

###############################################################################################
# import jtplot
#from jupyterthemes import jtplot

# you can select an alternative theme's plot style by name
# oceans16 | grade3 | chesterish | onedork | monokai | solarizedl
#jtplot.style('onedork')
###############################################################################################

plt.figure()
ax1 = plt.subplot(4, 1, 1).xaxis.set_visible(False)
plt.plot(df['Time'],df['VL'], linewidth=0.2, color = '#81a732')
plt.xlabel('Sample')
plt.ylabel('EMG (u.v.)')
plt.title('Original sinal'+'\nVL-d')

plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
plt.annotate('C1', xy=((2.087-0.599)/2+0.3, 30))  
plt.annotate('C2', xy=((1.5+0.744)+0.3, 30))
plt.annotate('C3', xy=((2*1.5+0.744)+0.3, 30))
plt.annotate('C4', xy=((3*1.5+0.744)+0.3, 30))
plt.annotate('C5', xy=((4*1.5+0.744)+0.3, 30))
plt.annotate('C6', xy=((5*1.5+0.744)+0.3, 30))
plt.annotate('C7', xy=((6*1.5+0.744)+0.3, 30))
plt.annotate('C8', xy=((7*1.5+0.744)+0.3, 30))

ax2 = plt.subplot(4, 1, 2).xaxis.set_visible(False)
plt.plot(df['Time'],df['GM'], linewidth=0.2, color = '#81a732')
#plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('GM-e')
plt.ylabel('EMG (u.v.)')

plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)


ax3 = plt.subplot(4, 1, 3).xaxis.set_visible(False)
plt.plot(df['Time'],df['SM'], linewidth=0.2, color = '#81a732')
#plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('SM-e')
plt.ylabel('EMG (u.v.)')

plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)

            
ax4 = plt.subplot(4, 1, 4)
plt.plot(df['Time'],df['BF'], linewidth=0.2, color = '#81a732')
plt.xlabel('Time (sec)')
plt.title('BF-d')
plt.ylabel('EMG (u.v.)')

plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %% [markdown]
# ## RMS Function

# %%
import numpy as np
def window_rms(a, window_size):
  a2 = np.power(a,2)
  window = np.ones(window_size)/float(window_size)
  return np.sqrt(np.convolve(a2, window, 'valid'))

# %%
l = ['VL', 'GM', 'SM', 'BF']
for i in l:
    u = df[i]

    rms = window_rms(u,100)

    df_rms = pd.DataFrame(rms)

    df_rms.plot(linewidth=0.8)
    plt.title('RMS: '+i)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %% [markdown]
# ## FFT Function

# %%
def plot_fft(x, fs):
    X =np.abs(np.fft.fft(x))
    f =np.linspace(0, fs,x.shape[0])
    plt.figure()
    plt.plot(f,X, linewidth=0.2)
    plt.xlabel("Frequency")
    plt.show()

# %%
l = ['VL', 'GM', 'SM', 'BF']
for i in l:
    plot_fft(df[i], 20)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
import scipy as sp
from scipy import signal
emg_correctmean = np.array(df['SM'])
time = np.array(df['Time'])
# create bandpass filter for EMG
high = 20./(1000./2.)
low = 450./(1000./2.)
b, a = sp.signal.butter(4, [high,low], btype='bandpass')

# process EMG signal: filter EMG
emg_filtered = sp.signal.filtfilt(b, a, emg_correctmean)

# plot comparison of unfiltered vs filtered mean-corrected EMG
fig = plt.figure()
plt.subplot(1, 2, 1)
plt.subplot(1, 2, 1).set_title('Unfiltered EMG')
plt.plot(time, emg_correctmean, linewidth=0.2)
plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
plt.xlabel('Time (sec)')
plt.ylabel('EMG (a.u.)')

plt.subplot(1, 2, 2)
plt.subplot(1, 2, 2).set_title('Filtered EMG')
plt.plot(time, emg_filtered, linewidth=0.2)
plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
plt.xlabel('Time (sec)')
plt.ylabel('EMG (a.u.)')

fig.tight_layout()
fig_name = 'fig3.png'
fig.set_size_inches(w=11,h=7)
fig.savefig(fig_name)
# Out:
# <img src="data:image/png;base64,..." width="1099.3999606823936">

# %%
def filteremg(time, emg, low_pass=10., sfreq=2000., high_band=20., low_band=450.):
    """
    time: Time data
    emg: EMG data
    high: high-pass cut off frequency
    low: low-pass cut off frequency
    sfreq: sampling frequency
    """
    
    # normalise cut-off frequencies to sampling frequency
    high_band = high_band/(sfreq/2)
    low_band = low_band/(sfreq/2)
    
    # create bandpass filter for EMG
    b1, a1 = sp.signal.butter(4, [high_band,low_band], btype='bandpass')
    
    # process EMG signal: filter EMG
    emg_filtered = sp.signal.filtfilt(b1, a1, emg)    
    
    # process EMG signal: rectify
    emg_rectified = abs(emg_filtered)
    
    # create lowpass filter and apply to rectified signal to get EMG envelope
    low_pass = low_pass/sfreq
    b2, a2 = sp.signal.butter(4, low_pass, btype='lowpass')
    emg_envelope = sp.signal.filtfilt(b2, a2, emg_rectified)
    
    # plot graphs
    fig = plt.figure()
    plt.subplot(1, 4, 1)
    plt.subplot(1, 4, 1).set_title('Unfiltered,' + '\n' + 'unrectified EMG')
    plt.plot(time, emg, linewidth=0.2)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.xlabel('Time (sec)')
    plt.ylabel('EMG (u.v.)')
    
    plt.subplot(1, 4, 2)
    plt.subplot(1, 4, 2).set_title('Filtered,' + '\n' + 'rectified EMG: ' + str(int(high_band*sfreq)) + '-' + str(int(low_band*sfreq)) + 'Hz')
    plt.plot(time, emg_rectified, linewidth=0.2)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.plot([0.9, 1.0], [1.0, 1.0], 'r-', lw=5)
    plt.xlabel('Time (sec)')

    plt.subplot(1, 4, 3)
    plt.subplot(1, 4, 3).set_title('Filtered, rectified ' + '\n' + 'EMG envelope: ' + str(int(low_pass*sfreq)) + ' Hz')
    plt.plot(time, emg_envelope)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.locator_params(axis='x', nbins=4)
    plt.locator_params(axis='y', nbins=4)
    plt.xlim(0.0500, 2.2090)
    #plt.ylim(0, 3800)

    plt.plot([0.9, 1.0], [1.0, 1.0], 'r-', lw=5)
    plt.xlabel('Time (sec)')
    
    plt.subplot(1, 4, 4)
    plt.subplot(1, 4, 4).set_title('Focussed region')
    plt.plot(time[int(0.9*1000):int(1.0*1000)], emg_envelope[int(0.9*1000):int(1.0*1000)])
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.xlabel('Time (sec)')

    fig_name = 'fig_' + str(int(low_pass*sfreq)) + '.png'
    fig.set_size_inches(w=11,h=7)
    fig.savefig(fig_name)

# show what different low pass filter cut-offs do
for i in [3, 10, 40]:
    filteremg(df['Time'], emg_correctmean, low_pass=i)
# Out:
# <img src="data:image/png;base64,..." width="1099.3999606823936">
# <img src="data:image/png;base64,..." width="1099.3999606823936">
# <img src="data:image/png;base64,..." width="1099.3999606823936">

# %%
def filteremg(time, emg, low_pass=10., sfreq=2000., high_band=20., low_band=450.):
    """
    time: Time data
    emg: EMG data
    high: high-pass cut off frequency
    low: low-pass cut off frequency
    sfreq: sampling frequency
    """
    
    # normalise cut-off frequencies to sampling frequency
    high_band = high_band/(sfreq/2)
    low_band = low_band/(sfreq/2)
    
    # create bandpass filter for EMG
    b1, a1 = sp.signal.butter(4, [high_band,low_band], btype='bandpass')
    
    # process EMG signal: filter EMG
    emg_filtered = sp.signal.filtfilt(b1, a1, emg)    
    
    # process EMG signal: rectify
    emg_rectified = abs(emg_filtered)
    
    # create lowpass filter and apply to rectified signal to get EMG envelope
    low_pass = low_pass/sfreq
    b2, a2 = sp.signal.butter(4, low_pass, btype='lowpass')
    emg_envelope = sp.signal.filtfilt(b2, a2, emg_rectified)
    
    return emg_envelope

def plot_fremg(df):   
    # plot graphs
    fig = plt.figure()
    

    plt.subplot(4, 1, 1).xaxis.set_visible(False)
    plt.subplot(4, 1, 1).set_title('Filtered, rectified ' + '\n' + 'EMG envelope: ' + str(int(40)) + ' Hz' + '\n VL-d')
    plt.plot(fr_emg['Time'], fr_emg['VL'])
    plt.locator_params(axis='x', nbins=4)
    plt.locator_params(axis='y', nbins=4)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.annotate('C1', xy=((2.087-0.599)/2+0.3, fr_emg['VL'].max()*.85))  
    plt.annotate('C2', xy=((1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C3', xy=((2*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C4', xy=((3*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C5', xy=((4*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C6', xy=((5*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C7', xy=((6*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.annotate('C8', xy=((7*1.5+0.744)+0.3, fr_emg['VL'].max()*.85))
    plt.ylabel('EMG (u.v.)')
    #plt.title('VL-d')
    
    plt.subplot(4, 1, 2).xaxis.set_visible(False)
    plt.plot(fr_emg['Time'], fr_emg['GM'])
    plt.locator_params(axis='x', nbins=4)
    plt.locator_params(axis='y', nbins=4)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.ylabel('EMG (u.v.)')
    plt.title('GM-e')
    
    plt.subplot(4, 1, 3).xaxis.set_visible(False)
    plt.plot(fr_emg['Time'], fr_emg['SM'])
    plt.locator_params(axis='x', nbins=4)
    plt.locator_params(axis='y', nbins=4)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.ylabel('EMG (u.v.)')
    plt.title('SM-e')
    
    plt.subplot(4, 1, 4)
    plt.plot(fr_emg['Time'], fr_emg['BF'])
    plt.locator_params(axis='x', nbins=4)
    plt.locator_params(axis='y', nbins=4)
    plt.axvspan(0.599, 2.087, facecolor='#F08080', alpha=0.5)
    plt.axvspan(2.086, 3.560, facecolor='#70659e', alpha=0.5)
    plt.axvspan(3.559, 5.034, facecolor='#F08080', alpha=0.5)
    plt.axvspan(5.033, 6.522, facecolor='#70659e', alpha=0.5)
    plt.axvspan(6.521, 7.997, facecolor='#F08080', alpha=0.5)
    plt.axvspan(7.996, 9.466, facecolor='#70659e', alpha=0.5)
    plt.axvspan(9.465, 11.017, facecolor='#F08080', alpha=0.5)
    plt.axvspan(11.016, 12.491, facecolor='#70659e', alpha=0.5)
    plt.ylabel('EMG (u.v.)')
    plt.title('BF-d')
    plt.xlabel('Time (sec)')
    
    

    fig_name = 'fig_' + str(int(40)) + '.png'
    fig.set_size_inches(w=11,h=7)
    fig.savefig(fig_name)

# show what different low pass filter cut-offs do
fr_emg = pd.DataFrame(df['Time'])

l = ['VL', 'GM', 'SM', 'BF']
for i in [40]:
    for j in l:
        emg_correctmean = np.array(df[j])
        fr_emg[j] = pd.DataFrame(filteremg(df['Time'], emg_correctmean, low_pass=i))

plot_fremg(fr_emg)
# Out:
# <img src="data:image/png;base64,..." width="1099.3999606823936">

# %%
fr_emg['VL'].max()
# Out:
# 5.7335985383968371
