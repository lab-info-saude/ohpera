# %%
import os
import pandas as pd

DATADIR = "DB_NG"
DATAFILE = "Marcha - João Vitor Galeno Araújo - Dia 17.04.29 as 18.23_data.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'VL-d', 'GM-e', 
                                                                    'SM-e', 'BF-d'])

df = df.dropna()

df.tail()

# %matplotlib notebook
import matplotlib.pyplot as plt

###############################################################################################
# import jtplot
#from jupyterthemes import jtplot

# you can select an alternative theme's plot style by name
# oceans16 | grade3 | chesterish | onedork | monokai | solarizedl
#jtplot.style('onedork')
###############################################################################################

plt.figure()
ax1 = plt.subplot(2, 1, 1).xaxis.set_visible(False)
plt.plot(df['VL-d'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('VL-d')
    
    
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1)
plt.plot(df['GM-e'], linewidth=0.2)
plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('GM-e')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-ead295379533> in <module>()
#       7 datafile = os.path.join(DATADIR, DATAFILE)
#       8 df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'VL-d', 'GM-e',
# ----> 9                                                                     'SM-e', 'BF-d'])
#      10
#      11 df = df.dropna()
#
# /home/collumbus/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /home/collumbus/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /home/collumbus/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /home/collumbus/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /home/collumbus/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# IOError: File DB_NG/Marcha - João Vitor Galeno Araújo - Dia 17.04.29 as 18.23_data.txt does not exist

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
DATADIR = "DATA_FGA"
DATAFILE = "coleta_2_data.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'Channel-1', 'Channel-2'])

df = df.dropna()

print df.tail()

# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
ax1 = plt.subplot(2, 1, 1).xaxis.set_visible(False)
plt.plot(df['Channel-1'], linewidth=0.2)
plt.xlabel('Sample')
plt.ylabel('mV').set_rotation(0)
plt.title('Channel 1 - RF PROXIMAL - sDS 500 - Gain 100')
    
    
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1)
plt.plot(df['Channel-2'], linewidth=0.2)
plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('Channel 2 - RF MEDIAL - sDS 500 - Gain 100')
# Out:
#           Time  Channel-1  Channel-2
# 59995  29.9975    0.34656  -0.625553
# 59996  29.9980    0.34656  -0.625553
# 59997  29.9985    0.34656  -0.625553
# 59998  29.9990    0.34656  -0.625553
# 59999  29.9995    0.34656  -0.625553
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
DATADIR = "DATA_FGA"
DATAFILE = "coleta_3_data.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'Channel-1', 'Channel-2'])

df = df.dropna()

df.tail()

# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
ax1 = plt.subplot(2, 1, 1).xaxis.set_visible(False)
plt.plot(df['Channel-1'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('Channel 1 - VL PROXIMAL - sDS 500 - Gain 100')
    
    
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1)
plt.plot(df['Channel-2'], linewidth=0.2)
plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('Channel 2 - VL PROXIMAL - sDS 500 - Gain 100')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
import numpy as np
def window_rms(a, window_size):
    a2 = np.power(a,2)
    window = np.ones(window_size)/float(window_size)
    return np.sqrt(np.convolve(a2, window, 'valid'))

u = df['Channel-2']

rms = window_rms(u,200)

df_rms = pd.DataFrame(rms)

df_rms.plot(linewidth=0.8)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
DATADIR = "DATA_FGA"
DATAFILE = "coleta_4_data.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'Channel-1', 'Channel-2'])

df = df.dropna()

df.tail()

# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
ax1 = plt.subplot(2, 1, 1).xaxis.set_visible(False)
plt.plot(df['Channel-1'], linewidth=0.2)
plt.xlabel('Sample')
plt.ylabel('mV').set_rotation(0)
plt.title('Channel 1 - RF PROXIMAL - sDS 500 - Gain 100')
    


# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1)
plt.plot(df['Channel-2'], linewidth=0.2)
plt.xlabel('Sample')
#plt.ylabel('mV')
plt.title('Channel 2 - RF PROXIMAL - sDS 500 - Gain 100')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %% [markdown]
# $\Huge{\textbf{TEST:} }$

# %%
DATADIR = "DATA_FGA"
DATAFILE = "coleta_2_data.txt"

import matplotlib.pyplot as plt

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep=",", skiprows=1, header=None, names=['Time', 'Channel-1', 'Channel-2'])

df = df.dropna()

print df.head()

#plt.figure()
df.plot(x='Time', y='Channel-2', linewidth=0.2)
# Out:
#      Time  Channel-1  Channel-2
# 0  0.0000   7.366263  -6.241609
# 1  0.0005   0.346560  -4.837595
# 2  0.0010   0.346560  -4.837595
# 3  0.0015   0.346560  -4.837595
# 4  0.0020  -1.057381  -3.433581
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
def plot_fft(x, fs):
    X =np.abs(np.fft.fft(x))
    f =np.linspace(0, fs,x.shape[0])
    plt.figure()
    plt.plot(f,X, linewidth=0.2)
    plt.xlabel("Frequency")
    plt.show()

# %%
import numpy as np 

plot_fft(df['Channel-2'], 20)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
from obspy.signal.filter import bandpass, bandstop, lowpass, highpass
import obspy

arr = np.array(df['Channel-2'])
test = obspy.signal.filter.highpass(arr, 1000, 2000, corners=4, zerophase=False)
# highpass(data, freq, df, corners=4, zerophase=False)[source]
plt.figure()
plt.plot(test, linewidth=0.2)
plt.xlabel('Time [s]')
plt.ylabel('sEMG [mV]')
plt.title('BF - Bandstop (100-200 [Hz])')
# Out:
# <img src="data:image/png;base64,...">
