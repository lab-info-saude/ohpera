# %%
import os
import pandas as pd

DATADIR = "A_TXT"
DATAFILE = "1Amar.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep="	", skiprows=7, header=None, names=['RF', 'BF', 'VM', 'ES', 'FE'])

df = df.dropna()

df.tail()
# Out:
#            RF      BF      VM      ES   FE
# 12968 -0.0046 -0.0015  0.0015 -0.0083 -7.2
# 12969 -0.0091 -0.0030 -0.0008 -0.0075 -7.0
# 12970 -0.0120 -0.0030 -0.0053 -0.0030 -7.2
# 12971 -0.0091 -0.0038 -0.0053 -0.0023 -7.2
# 12972 -0.0075 -0.0030 -0.0105 -0.0023 -7.2

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
plt.subplot(1, 2, 1)
plt.plot(df['RF'], linewidth=0.2)

plt.subplot(1, 2, 2)
plt.plot(df['BF'], linewidth=0.2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
ax1 = plt.subplot(2, 1, 1)
plt.plot(df['RF'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('Recto Femural')

    
    
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1).yaxis.set_visible(False)
plt.plot(df['BF'], linewidth=0.2)
plt.xlabel('Amostra')
#plt.ylabel('mV')
plt.title('Femoral Biceps')
# Out:
# <img src="data:image/png;base64,..." width="828">

# %%
plt.figure()
ax3 = plt.subplot(1, 2, 1)
plt.plot(df['VM'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('Vastus Medialis')
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax4 = plt.subplot(1, 2, 2, sharey=ax3).yaxis.set_visible(False)
plt.plot(df['ES'], linewidth=0.2)
plt.xlabel('Amostra')
#plt.ylabel('mV')
plt.title('Smitendinosus')
# Out:
# <img src="data:image/png;base64,..." width="869">

# %%
plt.figure()
ax5 = plt.plot
plt.plot(df['FE'], linewidth=0.5)
plt.xlabel('Amostra')
plt.ylabel('Deg').set_rotation(0)
plt.title('Flexion at the knee')
# Out:
# <img src="data:image/png;base64,..." width="858">
