# %%
import os
import pandas as pd

DATADIR = "N_TXT"
DATAFILE = "1Nmar.txt"

datafile = os.path.join(DATADIR, DATAFILE)
df = pd.read_csv(datafile, sep="	", skiprows=7, header=None, names=['RF', 'BF', 'VM', 'ES', 'FE'])

df = df.dropna()

df.tail()
# Out:
#           RF      BF      VM      ES   FE
# 5676  0.0015  0.0007 -0.0046  0.0015  6.9
# 5677 -0.0015  0.0030 -0.0046  0.0000  7.1
# 5678 -0.0030  0.0015  0.0045  0.0015  7.2
# 5679 -0.0046 -0.0015  0.0060  0.0030  7.4
# 5680  0.0127  0.0097 -0.0540 -0.0030  7.5

# %%
# import jtplot
#from jupyterthemes import jtplot

# you can select an alternative theme's plot style by name
# oceans16 | grade3 | chesterish | onedork | monokai | solarizedl
#jtplot.style('onedork')

# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
plt.subplot(1, 2, 1)
plt.plot(df['RF'], linewidth=0.2, color='#ffa31a')

plt.subplot(1, 2, 2)
plt.plot(df['BF'], linewidth=0.2, color='#ffa31a')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
plt.figure()
ax5 = plt.plot
plt.plot(df['BF'], linewidth=0.2)
plt.xlabel('Amostra')
#plt.ylabel('mV')
plt.title('Femoral Biceps')
# Out:
# <img src="data:image/png;base64,..." width="638.6333104940263">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
ax1 = plt.subplot(2, 1, 1)
plt.plot(df['RF'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('Recto Femural')

    
    
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(2, 1, 2, sharey=ax1).yaxis.set_visible(False)
plt.plot(df['BF'], linewidth=0.2)
plt.xlabel('Amostra')
#plt.ylabel('mV')
plt.title('Femoral Biceps')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
plt.figure()
ax3 = plt.subplot(1, 2, 1)
plt.plot(df['VM'], linewidth=0.2)
plt.xlabel('Amostra')
plt.ylabel('mV').set_rotation(0)
plt.title('Vastus Medialis')
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax4 = plt.subplot(1, 2, 2, sharey=ax3).yaxis.set_visible(False)
plt.plot(df['ES'], linewidth=0.2)
plt.xlabel('Amostra')
#plt.ylabel('mV')
plt.title('Smitendinosus')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
plt.figure()
ax5 = plt.plot
plt.plot(df['FE'], linewidth=0.5)
plt.xlabel('Amostra')
plt.ylabel('Deg').set_rotation(0)
plt.title('Flexion at the knee')
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
import numpy as np

rms = []
u = df['BF']
for i in u:
    rms.append(np.sqrt((1./len(u))*np.sum(u**2)))

# %%
import numpy as np
def window_rms(a, window_size):
  a2 = np.power(a,2)
  window = np.ones(window_size)/float(window_size)
  return np.sqrt(np.convolve(a2, window, 'valid'))

# %%
rms = window_rms(u,100)

# %%
df_rms = pd.DataFrame(rms)

df_rms.plot(linewidth=0.8)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">

# %%
df_rms.tail()
# Out:
#              0
# 5577  0.002030
# 5578  0.002002
# 5579  0.001973
# 5580  0.001978
# 5581  0.002198
