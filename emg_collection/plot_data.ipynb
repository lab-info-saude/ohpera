# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
from sklearn.neural_network import MLPRegressor

# %%
% %time
f = open("data_aq_1.txt","r")
data = f.readlines()
f.close()
x = np.zeros((len(data)))
j = 0
for i in data:
    x[j] = float(i.split()[0])
    j = j + 1
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
% %time
plt.plot(x)
plt.show()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs

# %%
% %time
md = np.mean(x)  
for i in xrange(0, x.shape[0]):
    if x[i] > 5: x[i] = md
    elif x[i] < 1: x[i] = md
x = x -md
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs

# %%
% %time
plt.plot(x)
plt.show()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs

# %%
% %time
X = np.fft.fft(x)
f = np.linspace(0, 1200.0, X.shape[0])
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
% %time
Nab = np.abs(X)
plt.plot(f,Nab)
plt.show()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs

# %%
% %time
n_buffer = 500
data = []
var  = np.zeros([n_buffer])
j = 0
xrms = []
xdiode = np.zeros(x.shape[0])
for i in xrange(0, x.shape[0]):
    var[j] = x[i]
    if x[i] <0: xdiode[i] = 0
    else: xdiode[i] = x[i]    
    if (j ==(n_buffer-1)): 
        data.append(var)
        xrms.append(np.sqrt(np.sum(pow(var,2))/n_buffer))
        j = 0
    else: j = j + 1
data = np.array(data)  
xrms = np.array(xrms)
print  data.shape, xrms.shape, xdiode.shape
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# (58, 500) (58,) (29000,)

# %%
% %time
plt.plot(xrms)
plt.title("RMS")
plt.show()
plt.plot(x)
plt.show()
plt.plot(xdiode)
plt.title("Positive values")
plt.show()
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 5.01 µs

# %%
reg =

# %%
reg.fit(data, xrms)
reg.score(data,xrms)
# Out:
# -3.2248648196286922e-11
